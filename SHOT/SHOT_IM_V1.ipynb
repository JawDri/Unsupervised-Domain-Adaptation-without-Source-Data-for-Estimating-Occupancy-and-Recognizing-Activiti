# %% [markdown]
# #Import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Prepare data

# %% [markdown]
# #AR: 3 Activities

# %%
import pandas as pd 
import numpy as np
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh103.zip
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !unzip '/content/hh101.zip'
# !unzip /content/hh103.zip

Final_Data_S1 = pd.read_csv("/content/hh103/hh103.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh101/hh101.ann.features.csv")

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Breakfast',  'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.activity.isin([ 'Cook_Breakfast',  'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Toilet'])].index,'activity']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Breakfast'])].index,'activity']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Toilet'])].index,'activity']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Breakfast'])].index,'activity']=2

Data_0 = Final_Data_S1[Final_Data_S1.activity == 0].iloc[:4000]#2000(#4000 for unbalanced)
Data_2 = Final_Data_S1[Final_Data_S1.activity == 1].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.activity == 2].iloc[:2000]#2000
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.activity == 0].iloc[:2000]#1000(#2000 for unbalanced)
Data_2 = Final_Data_S2[Final_Data_S2.activity == 1].iloc[:1000]#1000
Data_3 = Final_Data_S2[Final_Data_S2.activity == 2].iloc[:1000]#1000
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)


Source_train = Final_Data_S1.iloc[1000:,:]#1000
Source_test = Final_Data_S1.iloc[:1000,:]

Target_train = Final_Data_S2.iloc[500:,:]#500
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# --2022-10-05 01:55:03--  http://casas.wsu.edu/datasets/hh103.zip
# Resolving casas.wsu.edu (casas.wsu.edu)... 134.121.67.111
# Connecting to casas.wsu.edu (casas.wsu.edu)|134.121.67.111|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76057088 (73M) [application/zip]
# Saving to: ‘hh103.zip’
#
# hh103.zip           100%[===================>]  72.53M  31.3MB/s    in 2.3s
#
# 2022-10-05 01:55:05 (31.3 MB/s) - ‘hh103.zip’ saved [76057088/76057088]
#
# --2022-10-05 01:55:05--  http://casas.wsu.edu/datasets/hh101.zip
# Resolving casas.wsu.edu (casas.wsu.edu)... 134.121.67.111
# Connecting to casas.wsu.edu (casas.wsu.edu)|134.121.67.111|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35938924 (34M) [application/zip]
# Saving to: ‘hh101.zip’
#
# hh101.zip           100%[===================>]  34.27M  24.7MB/s    in 1.4s
#
# 2022-10-05 01:55:07 (24.7 MB/s) - ‘hh101.zip’ saved [35938924/35938924]
#
# Archive:  /content/hh101.zip
#    creating: hh101/
#   inflating: hh101/hh101.ann.features.README.txt
#   inflating: hh101/hh101.ann.features.csv
#   inflating: hh101/hh101.ann.txt
#   inflating: hh101/hh101.rawdata.txt
#   inflating: hh101/hh101.sensor_map.png
# Archive:  /content/hh103.zip
#    creating: hh103/
#   inflating: hh103/hh103.ann.features.README.txt
#   inflating: hh103/hh103.ann.features.csv
#   inflating: hh103/hh103.ann.txt
#   inflating: hh103/hh103.rawdata.txt
#   inflating: hh103/hh103.sensor_map.png

# %% [markdown]
# #AR: 5 activities

# %%
import pandas as pd 
import numpy as np
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh103.zip
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !unzip '/content/hh101.zip'
# !unzip /content/hh103.zip

Final_Data_S1 = pd.read_csv("/content/hh103/hh103.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh101/hh101.ann.features.csv")

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Lunch'])].index,'activity']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Toilet'])].index,'activity']=2
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Breakfast'])].index,'activity']=3
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.activity.isin(['Cook_Dinner'])].index,'activity']=4

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Watch_TV'])].index,'activity']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Lunch'])].index,'activity']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Toilet'])].index,'activity']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Breakfast'])].index,'activity']=3
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.activity.isin(['Cook_Dinner'])].index,'activity']=4

Data_0 = Final_Data_S1[Final_Data_S1.activity == 0].iloc[:4000]#2000(#4000 for unbalanced)
Data_1 = Final_Data_S1[Final_Data_S1.activity == 1].iloc[:2000]#2000
Data_2 = Final_Data_S1[Final_Data_S1.activity == 2].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.activity == 3].iloc[:2000]#2000
Data_4 = Final_Data_S1[Final_Data_S1.activity == 4].iloc[:4000]#2000(#4000 for unbalanced)
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.activity == 0].iloc[:2000]#1000(#2000 for unbalanced)
Data_1 = Final_Data_S2[Final_Data_S2.activity == 1].iloc[:1000]#1000
Data_2 = Final_Data_S2[Final_Data_S2.activity == 2].iloc[:1000]#1000
Data_3 = Final_Data_S2[Final_Data_S2.activity == 3].iloc[:1000]#1000
Data_4 = Final_Data_S2[Final_Data_S2.activity == 4].iloc[:2000]#1000(#2000 for unbalanced)
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[1000:,:]#1000#
Source_test = Final_Data_S1.iloc[:1000,:]

Target_train = Final_Data_S2.iloc[500:,:]#500#
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# --2022-06-24 15:43:42--  http://casas.wsu.edu/datasets/hh103.zip
# Resolving casas.wsu.edu (casas.wsu.edu)... 134.121.67.111
# Connecting to casas.wsu.edu (casas.wsu.edu)|134.121.67.111|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76057088 (73M) [application/zip]
# Saving to: ‘hh103.zip’
#
# hh103.zip           100%[===================>]  72.53M  45.0MB/s    in 1.6s
#
# 2022-06-24 15:43:44 (45.0 MB/s) - ‘hh103.zip’ saved [76057088/76057088]
#
# --2022-06-24 15:43:44--  http://casas.wsu.edu/datasets/hh101.zip
# Resolving casas.wsu.edu (casas.wsu.edu)... 134.121.67.111
# Connecting to casas.wsu.edu (casas.wsu.edu)|134.121.67.111|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35938924 (34M) [application/zip]
# Saving to: ‘hh101.zip’
#
# hh101.zip           100%[===================>]  34.27M  36.3MB/s    in 0.9s
#
# 2022-06-24 15:43:45 (36.3 MB/s) - ‘hh101.zip’ saved [35938924/35938924]
#
# Archive:  /content/hh101.zip
#    creating: hh101/
#   inflating: hh101/hh101.ann.features.README.txt
#   inflating: hh101/hh101.ann.features.csv
#   inflating: hh101/hh101.ann.txt
#   inflating: hh101/hh101.rawdata.txt
#   inflating: hh101/hh101.sensor_map.png
# Archive:  /content/hh103.zip
#    creating: hh103/
#   inflating: hh103/hh103.ann.features.README.txt
#   inflating: hh103/hh103.ann.features.csv
#   inflating: hh103/hh103.ann.txt
#   inflating: hh103/hh103.rawdata.txt
#   inflating: hh103/hh103.sensor_map.png

# %% [markdown]
# #OE: 2 labels unbalanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
frames = [Data_0, Data_2]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
frames = [Data_0, Data_2]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE: 3 labels unbalanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
Data_3 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:300]
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
Data_3 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:200]
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE: 2 labels balanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE: 3 labels balanced

# %%
import pandas as pd
import numpy as np
np.random.seed(2021)
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")


Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

Source_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SHOT_IM/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %% [markdown]
# #SHOT method

# %%
import os
os.chdir('/content/drive/MyDrive/SHOT_IM')

# %% [markdown]
# ##SHOT-IM

# %%
# !python uda_digit.py --dset s2m --gpu_id 0 --cls_par 0.0 --output ckps_digits
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:330/3300; Accuracy_Source = 74.86%/ 72.20%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:660/3300; Accuracy_Source = 86.54%/ 86.30%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:990/3300; Accuracy_Source = 83.63%/ 81.00%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1320/3300; Accuracy_Source = 88.40%/ 88.30%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1650/3300; Accuracy_Source = 91.43%/ 92.40%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1980/3300; Accuracy_Source = 90.89%/ 90.80%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:2310/3300; Accuracy_Source = 92.81%/ 92.90%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:2640/3300; Accuracy_Source = 91.71%/ 92.10%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:2970/3300; Accuracy_Source = 93.73%/ 93.00%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:3300/3300; Accuracy_Source = 94.49%/ 94.30%
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Task: s2m, Accuracy_Test_0 = 26.80%; f1_score_Test_1 = 0.11328706624605679; f_score_Test_1 = [0.         0.42271293 0.        ]; confusion_matrix_Test_1 = [[  0 254   0]
#  [  0 134   0]
#  [  0 112   0]]
#
# AxesSubplot(0.125,0.11;0.62x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:55/1650; Accuracy_Test_1 = 77.60%; f1_score_Test_1 = 0.785849205639669; f_score_Test_1 = [0.82758621 0.77108434 0.70886076]; confusion_matrix_Test_1 = [[180  19  55]
#  [  1  96  37]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.496x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:110/1650; Accuracy_Test_1 = 74.80%; f1_score_Test_1 = 0.7602695253606008; f_score_Test_1 = [0.81922197 0.72173913 0.67267267]; confusion_matrix_Test_1 = [[179  13  62]
#  [  4  83  47]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.3968x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:165/1650; Accuracy_Test_1 = 80.20%; f1_score_Test_1 = 0.8117795099627042; f_score_Test_1 = [0.86414254 0.78512397 0.72491909]; confusion_matrix_Test_1 = [[194  13  47]
#  [  1  95  38]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.31744x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:220/1650; Accuracy_Test_1 = 87.40%; f1_score_Test_1 = 0.877936373202032; f_score_Test_1 = [0.90280778 0.87878788 0.82051282]; confusion_matrix_Test_1 = [[209  14  31]
#  [  0 116  18]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.253952x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:275/1650; Accuracy_Test_1 = 53.60%; f1_score_Test_1 = 0.550836041127452; f_score_Test_1 = [0.55211268 0.59183673 0.49888641]; confusion_matrix_Test_1 = [[ 98   4 152]
#  [  3  58  73]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.203162x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:330/1650; Accuracy_Test_1 = 91.20%; f1_score_Test_1 = 0.9130869737990865; f_score_Test_1 = [0.93052632 0.89130435 0.89959839]; confusion_matrix_Test_1 = [[221  19  14]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.162529x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:385/1650; Accuracy_Test_1 = 89.00%; f1_score_Test_1 = 0.8926369429320428; f_score_Test_1 = [0.90517241 0.91111111 0.84210526]; confusion_matrix_Test_1 = [[210  13  31]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.130023x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:440/1650; Accuracy_Test_1 = 69.20%; f1_score_Test_1 = 0.7059471810489888; f_score_Test_1 = [0.76851852 0.66019417 0.61878453]; confusion_matrix_Test_1 = [[166   4  84]
#  [ 12  68  54]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.104019x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:495/1650; Accuracy_Test_1 = 92.20%; f1_score_Test_1 = 0.9233565509955223; f_score_Test_1 = [0.94166667 0.91449814 0.89243028]; confusion_matrix_Test_1 = [[226  12  16]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.083215x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:550/1650; Accuracy_Test_1 = 87.80%; f1_score_Test_1 = 0.8822339719750342; f_score_Test_1 = [0.91684435 0.86821705 0.82051282]; confusion_matrix_Test_1 = [[215  12  27]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.066572x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:605/1650; Accuracy_Test_1 = 90.60%; f1_score_Test_1 = 0.9079126352209521; f_score_Test_1 = [0.92372881 0.91111111 0.86821705]; confusion_matrix_Test_1 = [[218  13  23]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0532576x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:660/1650; Accuracy_Test_1 = 85.80%; f1_score_Test_1 = 0.8634819249787961; f_score_Test_1 = [0.89324619 0.86486486 0.79432624]; confusion_matrix_Test_1 = [[205  13  36]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0426061x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:715/1650; Accuracy_Test_1 = 90.00%; f1_score_Test_1 = 0.9023538818779421; f_score_Test_1 = [0.91684435 0.91449814 0.85496183]; confusion_matrix_Test_1 = [[215  12  27]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0340849x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:770/1650; Accuracy_Test_1 = 87.40%; f1_score_Test_1 = 0.8790412224893515; f_score_Test_1 = [0.91220557 0.875      0.80866426]; confusion_matrix_Test_1 = [[213  10  31]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0272679x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:825/1650; Accuracy_Test_1 = 86.60%; f1_score_Test_1 = 0.8711508143414544; f_score_Test_1 = [0.90280778 0.86821705 0.80286738]; confusion_matrix_Test_1 = [[209  12  33]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0218143x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:880/1650; Accuracy_Test_1 = 86.00%; f1_score_Test_1 = 0.8653373657116811; f_score_Test_1 = [0.89565217 0.86486486 0.79715302]; confusion_matrix_Test_1 = [[206  13  35]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0174514x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:935/1650; Accuracy_Test_1 = 90.00%; f1_score_Test_1 = 0.9023538818779421; f_score_Test_1 = [0.91684435 0.91449814 0.85496183]; confusion_matrix_Test_1 = [[215  12  27]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0139612x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:990/1650; Accuracy_Test_1 = 89.60%; f1_score_Test_1 = 0.8983614760052796; f_score_Test_1 = [0.91220557 0.91111111 0.85171103]; confusion_matrix_Test_1 = [[213  13  28]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0111689x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1045/1650; Accuracy_Test_1 = 90.40%; f1_score_Test_1 = 0.9065262169553095; f_score_Test_1 = [0.92144374 0.92134831 0.85496183]; confusion_matrix_Test_1 = [[217  10  27]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00893514x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1100/1650; Accuracy_Test_1 = 94.40%; f1_score_Test_1 = 0.9445228466004473; f_score_Test_1 = [0.95257732 0.94505495 0.92561983]; confusion_matrix_Test_1 = [[231  10  13]
#  [  0 129   5]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00714811x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1155/1650; Accuracy_Test_1 = 90.80%; f1_score_Test_1 = 0.9103161116907654; f_score_Test_1 = [0.92600423 0.92134831 0.86153846]; confusion_matrix_Test_1 = [[219  10  25]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00571849x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1210/1650; Accuracy_Test_1 = 92.00%; f1_score_Test_1 = 0.9217089142738722; f_score_Test_1 = [0.9394572  0.92134831 0.88188976]; confusion_matrix_Test_1 = [[225  10  19]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00457479x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1265/1650; Accuracy_Test_1 = 85.60%; f1_score_Test_1 = 0.8616256218568314; f_score_Test_1 = [0.89082969 0.86486486 0.79151943]; confusion_matrix_Test_1 = [[204  13  37]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00365983x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1320/1650; Accuracy_Test_1 = 86.80%; f1_score_Test_1 = 0.8735275862068965; f_score_Test_1 = [0.90517241 0.875      0.8       ]; confusion_matrix_Test_1 = [[210  10  34]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00292787x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1375/1650; Accuracy_Test_1 = 87.40%; f1_score_Test_1 = 0.8790412224893515; f_score_Test_1 = [0.91220557 0.875      0.80866426]; confusion_matrix_Test_1 = [[213  10  31]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00234229x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1430/1650; Accuracy_Test_1 = 92.00%; f1_score_Test_1 = 0.9217089142738722; f_score_Test_1 = [0.9394572  0.92134831 0.88188976]; confusion_matrix_Test_1 = [[225  10  19]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00187384x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1485/1650; Accuracy_Test_1 = 91.60%; f1_score_Test_1 = 0.917108503794363; f_score_Test_1 = [0.93501048 0.89781022 0.89959839]; confusion_matrix_Test_1 = [[223  17  14]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00149907x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1540/1650; Accuracy_Test_1 = 88.80%; f1_score_Test_1 = 0.891153903552192; f_score_Test_1 = [0.90752688 0.90636704 0.8358209 ]; confusion_matrix_Test_1 = [[211  12  31]
#  [  0 121  13]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00119925x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1595/1650; Accuracy_Test_1 = 89.60%; f1_score_Test_1 = 0.8990473619947305; f_score_Test_1 = [0.91452991 0.91729323 0.84210526]; confusion_matrix_Test_1 = [[214  10  30]
#  [  0 122  12]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.000959404x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Task: s2m, Iter:1650/1650; Accuracy_Test_1 = 91.80%; f1_score_Test_1 = 0.9191217004668636; f_score_Test_1 = [0.93723849 0.9010989  0.89959839]; confusion_matrix_Test_1 = [[224  16  14]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.000767523x0.77)

# %% [markdown]
# ##Full SHOT

# %%
# !python uda_digit.py --dset s2m --gpu_id 0 --cls_par 0.1 --output ckps_digits
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 24.74% -> 65.74%
#
# Task: s2m, Iter:55/1650; Accuracy_Test_1 = 80.00%; f1_score_Test_1 = 0.7980315970172802; f_score_Test_1 = [0.85773196 0.69264069 0.78873239]; confusion_matrix_Test_1 = [[208  17  29]
#  [ 23  80  31]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.62x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 80.86% -> 78.97%
#
# Task: s2m, Iter:110/1650; Accuracy_Test_1 = 81.00%; f1_score_Test_1 = 0.8098086636057126; f_score_Test_1 = [0.84434968 0.72519084 0.83271375]; confusion_matrix_Test_1 = [[198  33  23]
#  [ 17  95  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.496x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 82.49% -> 80.03%
#
# Task: s2m, Iter:165/1650; Accuracy_Test_1 = 76.20%; f1_score_Test_1 = 0.7676812758198897; f_score_Test_1 = [0.81118881 0.70895522 0.73927393]; confusion_matrix_Test_1 = [[174  39  41]
#  [  1  95  38]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.3968x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 77.14% -> 75.77%
#
# Task: s2m, Iter:220/1650; Accuracy_Test_1 = 81.00%; f1_score_Test_1 = 0.8125880217785845; f_score_Test_1 = [0.83218391 0.78596491 0.8       ]; confusion_matrix_Test_1 = [[181  39  34]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.31744x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 81.00% -> 80.09%
#
# Task: s2m, Iter:275/1650; Accuracy_Test_1 = 81.20%; f1_score_Test_1 = 0.8138179239375627; f_score_Test_1 = [0.84070796 0.76470588 0.8115942 ]; confusion_matrix_Test_1 = [[190  34  30]
#  [  8 104  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.253952x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 81.20% -> 80.66%
#
# Task: s2m, Iter:330/1650; Accuracy_Test_1 = 77.20%; f1_score_Test_1 = 0.7764383809742903; f_score_Test_1 = [0.80562061 0.74181818 0.75167785]; confusion_matrix_Test_1 = [[172  39  43]
#  [  1 102  31]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.203162x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 77.63% -> 76.77%
#
# Task: s2m, Iter:385/1650; Accuracy_Test_1 = 76.80%; f1_score_Test_1 = 0.7726462816752601; f_score_Test_1 = [0.79905437 0.74637681 0.74418605]; confusion_matrix_Test_1 = [[169  39  46]
#  [  0 103  31]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.162529x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 78.14% -> 77.37%
#
# Task: s2m, Iter:440/1650; Accuracy_Test_1 = 77.00%; f1_score_Test_1 = 0.7754755265820633; f_score_Test_1 = [0.8221709  0.70895522 0.74916388]; confusion_matrix_Test_1 = [[178  39  37]
#  [  1  95  38]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.130023x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 77.40% -> 76.69%
#
# Task: s2m, Iter:495/1650; Accuracy_Test_1 = 82.20%; f1_score_Test_1 = 0.8250631555848146; f_score_Test_1 = [0.84807256 0.8        0.80286738]; confusion_matrix_Test_1 = [[187  34  33]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.104019x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 81.77% -> 80.43%
#
# Task: s2m, Iter:550/1650; Accuracy_Test_1 = 82.40%; f1_score_Test_1 = 0.8268213304534794; f_score_Test_1 = [0.85067873 0.79432624 0.8115942 ]; confusion_matrix_Test_1 = [[188  36  30]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.083215x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.11% -> 81.63%
#
# Task: s2m, Iter:605/1650; Accuracy_Test_1 = 83.60%; f1_score_Test_1 = 0.8373637810679827; f_score_Test_1 = [0.84807256 0.82352941 0.82962963]; confusion_matrix_Test_1 = [[187  36  31]
#  [  0 119  15]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.066572x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.71% -> 81.74%
#
# Task: s2m, Iter:660/1650; Accuracy_Test_1 = 82.60%; f1_score_Test_1 = 0.8289529355220243; f_score_Test_1 = [0.85393258 0.79856115 0.80866426]; confusion_matrix_Test_1 = [[190  33  31]
#  [  1 111  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0532576x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 82.57% -> 82.00%
#
# Task: s2m, Iter:715/1650; Accuracy_Test_1 = 77.60%; f1_score_Test_1 = 0.7776125830196768; f_score_Test_1 = [0.88453159 0.72043011 0.6035503 ]; confusion_matrix_Test_1 = [[203  45   6]
#  [  0 134   0]
#  [  2  59  51]]
#
# AxesSubplot(0.125,0.11;0.0426061x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 77.17% -> 79.63%
#
# Task: s2m, Iter:770/1650; Accuracy_Test_1 = 80.40%; f1_score_Test_1 = 0.8099640548333116; f_score_Test_1 = [0.88596491 0.74651811 0.71351351]; confusion_matrix_Test_1 = [[202  45   7]
#  [  0 134   0]
#  [  0  46  66]]
#
# AxesSubplot(0.125,0.11;0.0340849x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 80.83% -> 83.43%
#
# Task: s2m, Iter:825/1650; Accuracy_Test_1 = 83.40%; f1_score_Test_1 = 0.8369681615851307; f_score_Test_1 = [0.86353468 0.80286738 0.81751825]; confusion_matrix_Test_1 = [[193  33  28]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0272679x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.77% -> 83.57%
#
# Task: s2m, Iter:880/1650; Accuracy_Test_1 = 82.80%; f1_score_Test_1 = 0.8310840277799635; f_score_Test_1 = [0.85585586 0.80286738 0.80866426]; confusion_matrix_Test_1 = [[190  33  31]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0218143x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.40% -> 82.40%
#
# Task: s2m, Iter:935/1650; Accuracy_Test_1 = 79.20%; f1_score_Test_1 = 0.7973116349546508; f_score_Test_1 = [0.83218391 0.76296296 0.75932203]; confusion_matrix_Test_1 = [[181  33  40]
#  [  0 103  31]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0174514x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 79.31% -> 78.57%
#
# Task: s2m, Iter:990/1650; Accuracy_Test_1 = 82.60%; f1_score_Test_1 = 0.8288968660757706; f_score_Test_1 = [0.85327314 0.79715302 0.8115942 ]; confusion_matrix_Test_1 = [[189  35  30]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.0139612x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.23% -> 83.03%
#
# Task: s2m, Iter:1045/1650; Accuracy_Test_1 = 88.60%; f1_score_Test_1 = 0.8871592214024556; f_score_Test_1 = [0.90128755 0.84827586 0.90163934]; confusion_matrix_Test_1 = [[210  33  11]
#  [  0 123  11]
#  [  2   0 110]]
#
# AxesSubplot(0.125,0.11;0.0111689x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 88.49% -> 88.17%
#
# Task: s2m, Iter:1100/1650; Accuracy_Test_1 = 88.60%; f1_score_Test_1 = 0.8870804250995575; f_score_Test_1 = [0.9004329  0.84827586 0.90322581]; confusion_matrix_Test_1 = [[208  33  13]
#  [  0 123  11]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00893514x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 89.40% -> 88.14%
#
# Task: s2m, Iter:1155/1650; Accuracy_Test_1 = 80.80%; f1_score_Test_1 = 0.8124799479372805; f_score_Test_1 = [0.85393258 0.75836431 0.78321678]; confusion_matrix_Test_1 = [[190  33  31]
#  [  1 102  31]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00714811x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 81.51% -> 81.26%
#
# Task: s2m, Iter:1210/1650; Accuracy_Test_1 = 82.60%; f1_score_Test_1 = 0.8288968660757706; f_score_Test_1 = [0.85327314 0.79715302 0.8115942 ]; confusion_matrix_Test_1 = [[189  35  30]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00571849x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.11% -> 82.80%
#
# Task: s2m, Iter:1265/1650; Accuracy_Test_1 = 82.40%; f1_score_Test_1 = 0.8271555490682625; f_score_Test_1 = [0.85067873 0.80286738 0.80286738]; confusion_matrix_Test_1 = [[188  33  33]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00457479x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 82.09% -> 81.51%
#
# Task: s2m, Iter:1320/1650; Accuracy_Test_1 = 82.20%; f1_score_Test_1 = 0.8251893204593665; f_score_Test_1 = [0.84807256 0.80286738 0.8       ]; confusion_matrix_Test_1 = [[187  33  34]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00365983x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 81.57% -> 80.89%
#
# Task: s2m, Iter:1375/1650; Accuracy_Test_1 = 82.00%; f1_score_Test_1 = 0.8232216454523422; f_score_Test_1 = [0.84545455 0.80286738 0.79715302]; confusion_matrix_Test_1 = [[186  33  35]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00292787x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 81.40% -> 80.86%
#
# Task: s2m, Iter:1430/1650; Accuracy_Test_1 = 84.20%; f1_score_Test_1 = 0.8436327908327909; f_score_Test_1 = [0.85585586 0.83216783 0.82962963]; confusion_matrix_Test_1 = [[190  33  31]
#  [  0 119  15]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00234229x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 84.09% -> 83.00%
#
# Task: s2m, Iter:1485/1650; Accuracy_Test_1 = 82.80%; f1_score_Test_1 = 0.8310840277799635; f_score_Test_1 = [0.85585586 0.80286738 0.80866426]; confusion_matrix_Test_1 = [[190  33  31]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00187384x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.43% -> 82.60%
#
# Task: s2m, Iter:1540/1650; Accuracy_Test_1 = 82.40%; f1_score_Test_1 = 0.8271555490682625; f_score_Test_1 = [0.85067873 0.80286738 0.80286738]; confusion_matrix_Test_1 = [[188  33  33]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00149907x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 82.29% -> 82.06%
#
# Task: s2m, Iter:1595/1650; Accuracy_Test_1 = 82.80%; f1_score_Test_1 = 0.8310840277799635; f_score_Test_1 = [0.85585586 0.80286738 0.80866426]; confusion_matrix_Test_1 = [[190  33  31]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.00119925x0.77)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy = 83.40% -> 82.71%
#
# Task: s2m, Iter:1650/1650; Accuracy_Test_1 = 83.00%; f1_score_Test_1 = 0.8330464591070419; f_score_Test_1 = [0.85842697 0.80286738 0.8115942 ]; confusion_matrix_Test_1 = [[191  33  30]
#  [  0 112  22]
#  [  0   0 112]]
#
# AxesSubplot(0.125,0.11;0.000959404x0.77)
